# %% [markdown]
# ### Import Necessary Libraries

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %% [markdown]
# ## Create date Variables

# %%
start= datetime.datetime(2006,1,1)
end=   datetime.datetime(2016,1,1)

# %%
###  Get Remote Data
## Bank Of America  BAC
BAC = data.DataReader('BAC','yahoo',start,end)
## CitiGroup  C
C = data.DataReader('C','yahoo',start,end)
## Goldman Sachs GS
GS = data.DataReader('GS','yahoo',start,end)
##JPMorgan Chase  JPM
JPM = data.DataReader('JPM','yahoo',start,end)
##Morgan Stanley  MS
MS = data.DataReader('MS','yahoo',start,end)
## Wells Fargo  WFC
WFC = data.DataReader('WFC','yahoo',start,end)

# %% [markdown]
# ### CREATE A LIST OF STOCK TICKER SYMBOLS (AS STRINGS) IN ALPHABETICAL ORDER, AND CALL THE LIST TICKERS

# %%
tickers = ['BAC','C','GS','JPM','MS','WFC']

# %% [markdown]
# ### Use pd.cocat to concatenate the bank dataframes into a single dataframe called bank_stocks

# %%
bank_stocks = pd.concat([BAC,C,GS,JPM,MS,WFC], axis=1, keys=tickers)

# %% [markdown]
# ### Check the head of the bank_stocks dataframe

# %%
bank_stocks.columns.names =(['ticker','stock info'])

# %%
bank_stocks.head()
# Out:
# ticker            BAC                                                          \
# stock info       High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  35.523922
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  35.146645
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  35.191933
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  35.139107
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  35.161732
#
# ticker               C                                      ...         MS  \
# stock info        High         Low        Open       Close  ...       Open
# Date                                                        ...
# 2006-01-03  493.799988  481.100006  490.000000  492.899994  ...  57.169998
# 2006-01-04  491.000000  483.500000  488.600006  483.799988  ...  58.700001
# ...

# %% [markdown]
# ## EDA Exporatory Data Analysis

# %% [markdown]
# ### Max Stock Close price for each of the banks through the period

# %%
### Using for loop
for tick in tickers:
    print(tick,bank_stocks[tick]['Close'].max())
# Out:
# BAC 54.900001525878906
# C 564.0999755859375
# GS 247.9199981689453
# JPM 70.08000183105469
# MS 89.30000305175781
# WFC 58.52000045776367

# %%
### Using Pandas cross section xs()
bank_stocks.xs(key='Close', axis=1, level='stock info').max()
# Out:
# ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %%
### Create a new empty Returns dataframe

# %%
returns = pd.DataFrame()

# %%
### Create a forloop that that goes for each Stock ticker creates this returns column in the returns datframe

# %%
for tick in tickers:
    returns[tick + ' Return'] = bank_stocks[tick]['Close'].pct_change()

# %%
returns
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158
# 2006-01-10   -0.008369  0.003100   0.012578    0.001475   0.000507   -0.000789
# 2006-01-11   -0.002380  0.009065  -0.000454   -0.000737   0.005910    0.005213
# 2006-01-12   -0.006508  0.001021   0.002122   -0.018428  -0.001679   -0.011630
# 2006-01-13    0.000000 -0.002243   0.007637   -0.000751  -0.001513    0.005724
# 2006-01-17   -0.010699 -0.010016  -0.005028   -0.005260  -0.009599   -0.010277
# 2006-01-18   -0.001104 -0.001445  -0.001659   -0.010829  -0.006121    0.015974
# ...
